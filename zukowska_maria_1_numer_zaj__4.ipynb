# %% [markdown]
# <a href="https://colab.research.google.com/github/mariophobia/python-basics/blob/main/zukowska_maria_1_numer_zaj__4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#prototyp formularza rejestracji na stronie
print("=== Rejestracja użytkownika ===")
imie= input("Jak masz na imię:")
if imie.isdigit():
   print("Blad, imie nie moze byc liczba")
else:
  print("ok")
nazwisko = input("Jak masz na nazwisko:")
if nazwisko.isdigit():
  print("Blad, nazwisko nie moze byc liczba")
else:
   print("ok")
wiek =input("Ile masz lat")
if not wiek.isdigit():
  print("Wiek musi być liczbą!")
#hasło
haslo1 = input("Hasło: ")
haslo2 = input("Powtórz hasło: ")
while haslo1 != haslo2:
  print("Hasła się nie zgadzają, spróbuj ponownie.")
  haslo1 = input("Hasło: ")
  haslo2 = input("Powtórz hasło: ")
haslo = haslo1
#nrtel
numer_telefonu=input("Podaj numer telefonu")
dozwolone ="1234567890 -"
if not all(znak in dozwolone for znak in numer_telefonu):
  print("Błędny numer telefonu!")
else:
  numer_plynny=numer_telefonu.replace(" ", "").replace("-", "")
if len(numer_plynny) == 9 and numer_plynny.isdigit():
  print ("Numer poprawy")
else:
  print("numer niepoprawny")
  print("\nWprowadzone dane:")
print("Imię:", imię)
print("Nazwisko:", nazwisko)
print("Wiek:", wiek)
print("Telefon:", numer_plynny)
# Out:
# === Rejestracja użytkownika ===
# Jak masz na imię:maria
# ok
# Jak masz na nazwisko:zukowska
# ok
# Ile masz lat23
# Hasło: haslo123
# Powtórz hasło: haslo123
# Podaj numer telefonu123456789
# Numer poprawy
# Imię: maria
# Nazwisko: zukowska
# Wiek: 23
# Telefon: 123456789

# %%
print(" KALKULATOR ")
a = input("Podaj pierwsza liczbe:")
b = input("podaj druga liczbe:")
if not a.isdigit() or not b.isdigit():
  print("blad, liczby musza byc calkowite")
else:
  a = float(a)
  b = float(b)
  print("Wybierz działanie:")
  print("1 - Dodawanie")
  print("2 - Odejmowanie")
  print("3 - Mnożenie")
wybor = input("Twoj wybor: ")
print("4 - Dzielenie")
elif wybor = "2":
  print("Wynik:", a - b)
elif wybor = "3":
  print("Wynik:", a * b)
elif wybor = "4":
if b == 0:
  print("BŁĄD! Nie można dzielić przez 0!")
else:
 print("Wynik:", a / b)
# Out:
#   File "/tmp/ipython-input-3968719679.py", line 15
#     elif wybor = "2":
#     ^
# SyntaxError: invalid syntax
